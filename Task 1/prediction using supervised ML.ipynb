# %% [markdown]
#   SIMPLE LINEAR REGRESSION
#
#   In given task we have to predict the percentage of marks expected by the student based upon the number of hours they
#   studied.In this task only two variables are involved.

# %%
# Importing all the required libraries

import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
# Reading data from remote link

url = "http://bit.ly/w-data"
data = pd.read_csv(url)

# %%
# Displaying the first 10 rows of the data

data.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %% [markdown]
#   DATA VISUALIZATION
#
#  Now let's plot a graph of our data so that it will give us clear idea about dat

# %%
# Plotting the dataset

data.plot(x='Hours', y='Scores', style='*', color='blue', markersize=7)  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.grid()
plt.show()

# %% [markdown]
#   Linear Regression Model
#
#   Now we prepare the data and split it in test data

# %%
X = data.iloc[:, :-1].values  
Y = data.iloc[:, 1].values

# %%
# Splitting data into training and testing data

from sklearn.model_selection import train_test_split  
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, 
                            test_size=0.2, random_state=0)

# %% [markdown]
#   Training the Algorithm
#
#   Now the spliting of our data into training and testing sets is done, now it's time to train our algorithm.

# %%
from sklearn.linear_model import LinearRegression  

model = LinearRegression()  
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
line = model.coef_*X + model.intercept_

# Plotting for the training data
plt.scatter(X_train, Y_train, color='orange')
plt.plot(X, line, color='pink');
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score') 
plt.grid()
plt.show()

# %%
# Plotting for the testing data

plt.scatter(X_test, Y_test, color='orange')
plt.plot(X, line, color='pink');
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score') 
plt.grid()
plt.show()

# %% [markdown]
#   Now we make predictions

# %%
Y_predicted = model.predict(X_test)

# %%
# Comparing Actual vs Predicted

df = pd.DataFrame({'Actual score': Y_test, 'Predicted score': Y_predicted})  
df
# Out:
#    Actual score  Predicted score
# 0            20        16.884145
# 1            27        33.732261
# 2            69        75.357018
# 3            30        26.794801
# 4            62        60.491033

# %%
# Testing with your own data

hours = 9.25
own_pred = model.predict([[hours]])
print("The predicted score if a person studies for",hours,"hours is",own_pred[0])
# Out:
# The predicted score if a person studies for 9.25 hours is 93.69173248737538

# %% [markdown]
#   Model Evaluation Metrics

# %%
from sklearn import metrics  

print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_predicted))
# Out:
# Mean Absolute Error: 4.183859899002975
